# %%
# import packages
import urllib.parse
import urllib.request
import urllib.error
import os

from bs4 import BeautifulSoup

#location = 'C:\\Users\\kbp2w\\Box Sync\\Sally\\Wisconsin\\Unions\\documentation\\downloaded via python\\handbooks and compensation docs\\'
#months = ['03','04','05','06','07','08']
#
#for month in months:
#	print ('Current month :', month)
#	url = 'https://dev.wasb.org/wp-content/uploads/2017/' + month + '/'
#	download_path = location + "\\2017-" + month
#	file_type = '.pdf'
#
#	response = urllib.request.urlopen(url)
#	html = str(response.read())
#
#	soup = BeautifulSoup(html) # to parse the website
#
#	for tag in soup.find_all('a', href=True):
#		print ('Found the URL:', tag['href'])
#		# so that if it doesn't contain the full url it can use the url itself to it for the download
#		tag['href'] = urllib.parse.urljoin(url, tag['href'])
#		if os.path.splitext(os.path.basename(tag['href']))[1] == file_type:
#			current = urllib.request.urlopen(tag['href'])
#		
#			f = open(download_path + "\\" + os.path.basename(tag['href']), "wb")
#			f.write(current.read())
#			f.close
#
#print('****')
#print('DONE')
#print('****')

#%% creates a cell; so I can run just this cell/chunk on its own using SHIFT + ENTER

# %%
#location = "C:\\Users\\kbp2w\\Box Sync\\Machine Learning\\The Economics of Artificial Intelligence\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\time_limits\\state_data\\indiana\\pdfs\\2019andCounty\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\time_limits\\state_data\\oregon\\pdfs\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\time_limits\\qc\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\time_limits\\state_data\\wisconsin\\pdfs\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\time_limits\\state_data\\north carolina\\timeliness\\"
#location = "C:\\Users\\Kelsey\\Google Drive\\Harvard\\research\\medicaid\\texas\\"
location = "C:\\Users\\Kelsey\\Downloads\\"
#location = "G:\\My Drive\\Harvard\\research\\time_limits\\state_data\\westvirginia\\pdfs\\"

#url = 'http://papers.nber.org/books/agra-1' 
#url = 'https://www.in.gov/fssa/dfr/3924.htm'
#url = 'https://www.in.gov/fssa/dfr/2688.htm'
#url = 'https://dfcs.georgia.gov/dfcs-descriptive-data-reports-year'
#url = 'https://dss.mo.gov/re/fsd_mhdmr.htm'
#url = 'https://web.archive.org/web/20160511045941/https://dphhs.mt.gov/StatisticalInformation/DPHHSProgramStatistics'
#url = 'http://dhhs.ne.gov/Pages/ACCESSNebraska-Performance-Measures.aspx'
#url = 'https://www.ncdhhs.gov/divisions/social-services/program-statistics-and-reviews/work-first-program-evaluation'
#url = 'https://dss.sd.gov/economicassistance/snap/data.aspx'
#url = 'https://dss.sc.gov/about/data-and-resources/family-assistance-data/supplemental-nutrition-assistance-program'
#url = 'https://www.oregon.gov/DHS/ASSISTANCE/Pages/data-pa.aspx?&&p_SortBehavior=0&p_Title=2018&p_Date_x0020_M_x002f_D_x002f_YYYY=20180809%2007%3a00%3a00&&PageFirstRow=1&&View={0FA5817C-852E-4A0F-A2D4-0932D13928F2}'
#url = 'https://host76.mathematica-mpr.com/fns/Download.aspx?'
#url = 'https://dhr.alabama.gov/facts-and-figures/'
#url = 'http://humanservices.hawaii.gov/reports/dhs-annual-data-books/'
#url = 'https://www.nj.gov/humanservices/dfd/news/cps.html'
#url = 'https://www.hsd.state.nm.us/monthly-statistical-reports.aspx'
#url = 'http://otda.ny.gov/resources/caseload/'
#url = 'http://www.nd.gov/dhs/info/pubs/help.html'
#url = 'http://jfs.ohio.gov/PAMS/index.stm'
#url = 'https://www.tn.gov/content/tn/humanservices/for-families/supplemental-nutrition-assistance-program-snap/snap-statistical-information.html'
#url ='https://hhs.texas.gov/about-hhs/records-statistics/data-statistics/supplemental-nutritional-assistance-program-snap-statistics'
#url = 'https://www.dhs.wisconsin.gov/foodshare/rsdata.htm'
#url = 'https://www.dss.virginia.gov/geninfo/reports/financial_assistance/fs.cgi'
#url = 'https://www.maine.gov/dhhs/ofi/reports/2019/index.shtml'
#url = 'https://www.ncdhhs.gov/divisions/social-services/program-statistics-and-reviews/fns-caseload-statistics-reports/quality'
#url = 'https://www.ncdhhs.gov/divisions/social-services/program-statistics-and-reviews/fns-caseload-statistics-reports/fns-0'
#url = 'https://www.ncdhhs.gov/divisions/social-services/program-statistics-and-reviews/fns-caseload-statistics-reports/fns-0#2019'
#url = 'https://www.ncdhhs.gov/divisions/social-services/program-statistics-and-reviews/fns-caseload-statistics-reports/fns#2020'
#url = 'https://hhs.texas.gov/about-hhs/records-statistics/data-statistics/healthcare-statistics'
#url = 'https://www.dol.gov/agencies/eta/performance/results/wia'
#url = 'https://dhhr.wv.gov/bcf/Reports/Pages/Bureau-for-Children-and-Families-Secretary\'s-Report.aspx'
url = 'https://www.mass.gov/lists/dta-performance-scorecards'

download_path = location
#file_type = '.xlsm'
file_type = '.pdf'
#file_type = '.csv'
#file_type = '.doc'
    
response = urllib.request.urlopen(url)
html = str(response.read())
    
soup = BeautifulSoup(html) # to parse the website
    
# get xpath if it exists. if it does not exist, then just replace info with an empty string
#def get_file(download_path = download_path):
#    try:
#        f = open(download_path + "\\" + os.path.basename(tag['href']), "wb")
#        f.write(current.read())
#        f.close
#    except:
#        print("could not download file")
    #return 

for tag in soup.find_all('a', href=True):
    print ('Found the URL:', tag['href'])
    # so that if it doesn't contain the full url it can use the url itself to it for the download
    tag['href'] = urllib.parse.urljoin(url, tag['href'])
    if os.path.splitext(os.path.basename(tag['href']))[1] == file_type:
        current = urllib.request.urlopen(tag['href'])
            
        f = open(download_path + "\\" + os.path.basename(tag['href']), "wb")
        f.write(current.read())
        f.close
   
print('****')
print('DONE')
print('****')
    #%% 
########################################################
# Out:
# Found the URL: #main-content
# Found the URL: /info-details/massachusetts-state-organizations-a-to-z
# Found the URL: https://sso.hhs.state.ma.us/vgportal/login
# Found the URL: https://uionline.detma.org/Claimant/Core/Login.ASPX
# Found the URL: https://ecse.cse.state.ma.us/ECSE/Login/login.asp
# Found the URL: /
# Found the URL: /topics/health-social-services
# Found the URL: /topics/families-children
# Found the URL: /topics/housing-property
# Found the URL: /topics/transportation
# Found the URL: /topics/legal-justice
# Found the URL: /topics/public-safety
# Found the URL: /topics/energy
# Found the URL: /topics/environment
# Found the URL: /topics/taxes
# Found the URL: /topics/unclaimed-property
# Found the URL: /topics/vital-public-records
# Found the URL: /topics/voting
# Found the URL: /topics/living
# Found the URL: /topics/business-resources
# Found the URL: /topics/professional-licenses-permits
# Found the URL: /topics/unemployment
# Found the URL: /topics/finding-a-job
# Found the URL: /topics/taxes
# Found the URL: /topics/workers-rights-safety
# Found the URL: /topics/industry-regulations
# Found the URL: /topics/state-employee-resources
# Found the URL: /topics/working
# Found the URL: /topics/early-childhood-education-care
# Found the URL: /topics/elementary-secondary-schools
# Found the URL: /topics/higher-education
# Found the URL: /topics/continuing-education
# Found the URL: /topics/for-educators-administrators
# Found the URL: /topics/learning
# Found the URL: /topics/parks-recreation
# Found the URL: /topics/fishing-hunting
# Found the URL: /topics/historic-sites
# Found the URL: /topics/arts
# Found the URL: /topics/family-fun
# Found the URL: /topics/travel-options
# Found the URL: /topics/seasonal-activities
# Found the URL: /topics/exploring-massachusetts
# Found the URL: /topics/executive-branch
# Found the URL: /topics/constitutionals-independents
# Found the URL: /topics/legislative-branch
# Found the URL: /topics/judicial-branch
# Found the URL: /topics/cities-towns
# Found the URL: https://www.mass.gov/info-details/massachusetts-state-organizations-a-to-z
# Found the URL: /topics/your-government
# Found the URL: /covid-19-updates-and-information
# Found the URL: /info-details/massachusetts-state-organizations-a-to-z
# Found the URL: https://sso.hhs.state.ma.us/vgportal/login
# Found the URL: https://uionline.detma.org/Claimant/Core/Login.ASPX
# Found the URL: https://ecse.cse.state.ma.us/ECSE/Login/login.asp
# Found the URL: /
# Found the URL: /
# Found the URL: /topics/your-government
# Found the URL: /topics/public-records-requests
# Found the URL: /topics/executive-office-of-health-and-human-services-public-records-requests
# Found the URL: /dta-public-records
# Found the URL: /orgs/department-of-transitional-assistance
# Found the URL: #ma-end-sticky-toc
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2022-this-version-was-updated-from-the-previously-published-report/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2022-this-version-was-updated-from-the-previously-published-report-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2022/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2022-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2021-with-the-current-month-data/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2021-with-the-current-month-data-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2021/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2021-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2020-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2020/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2019-1/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2019-2/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2019-1/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2019-2/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2019/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2019-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2019-1/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2019-2/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2018-1/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2018-3/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2018-6/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2018-8/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2018-2/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2018-3/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2018-5/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2018-6/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2018-3/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2018-4/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2018-1/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-may-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-april-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-march-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-february-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2018-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-january-2018/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-december-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-november-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-october-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-september-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-august-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-july-2017/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2017-0/download
# Found the URL: https://www.mass.gov/doc/performance-scorecard-june-2017/download
# Found the URL: https://www.mass.gov/user-panel?utm_source=survey
# Found the URL: /
# Found the URL: /topics/massachusetts-topics
# Found the URL: /site-policies
# Found the URL: /topics/public-records-requests
# Found the URL: /privacypolicy
# Found the URL: #feedback
# ****
# DONE
# ****

# %%
#suffixs = ['29783', '29904', '30199', '30293', '30294', '30484', '30610', '30717', '30830', '26659', '26895', '27299', '27559', '27763', '27934', '28098', '28208', '28305', '28478', '29382', '29274', '23463', '23684', '23907', '24236', '24427', '24709', '24916', '25132', '25379', '25935', '25932', '26363', '23343', '23355', '23356', '23357', '23358', '23359']
#suffixs = ['21475', '21695', '21879', '22024', '22630', '22637', '18810', '18954', '19247', '19494', '19825', '20020', '19827', '20321', '20512', '20630', '20751', '21270', '16845', '17020', '17186', '17538', '17660', '17813', '17918', '18128', '18384']
#suffixs = ['14842', '15013', '15115', '15656', '15658', '15838', '12054', '12129', '12838', '13550', '13139', '13298', '13498', '13725', '13757', '13848', '13980', '14073', '10219', '10373', '10506', '10743', '11013', '11160', '11344', '11503', '11557', '11621', '11686', '11900', '9160', '9252', '9459', '9505', '9622', '9753', '9792', '9873', '9908', '9973', '10049', '10151', '6916', '6987', '7141', '7258', '7314', '7398', '7611', '8093', '8520', '8864', '9015', '9078', '6141', '6143', '6144', '5810', '6234']
#suffixs = ['6224', '6263', '6393', '6481', '6520', '6581', '6735', '6798', '6861', '00004645', '00004896', '00005008', '00005010', '00005176', '00005222', '00005392', '00005402', '00005428', '00005716', '00003457', '00003499', '00003592', '00003641', '00005728', '00003970', '00004053', '00004109', '00004178', '00004402', '00004403', '00004582', '00002170', '00002266', '00002395', '00002467', '00002665', '00002716', '00002763', '00002827', '00002993', '00003194', '00003197', '00003305', '00001058', '00001172', '00001506', '00001249', '00001626', '00001348', '00001591', '00001832', '00001860', '00001932', '00001980', '00002130', '00004192', '00004193', '00004194', '00004195', '00004196', '00001710', '00004197', '00004198', '00004199', '00004200', '00004189', '00000765', '00004184', '00004185', '00001673', '00001674', '00004186', '00004187', '00004188', '00001675', '00004190', '00001672', '00004183', '00004191']
#suffixs = ['2013','2012','2011','2010','2009','2008','2007','2006','2005']
stop

for suffix in suffixs:
    print ('Current link: ',suffix)
    #url = 'http://publications.iowa.gov/' + suffix + '/'
    url = 'https://www.maine.gov/dhhs/ofi/reports/' + suffix + '/index.html'
    
    download_path = location + suffix + "\\"
    file_type = '.pdf'
    
    response = urllib.request.urlopen(url)
    html = str(response.read())
    
    soup = BeautifulSoup(html) # to parse the website
    
    for tag in soup.find_all('a', href=True):
        print ('Found the URL:', tag['href'])
        # so that if it doesn't contain the full url it can use the url itself to it for the download
        tag['href'] = urllib.parse.urljoin(url, tag['href'])
        if os.path.splitext(os.path.basename(tag['href']))[1] == file_type:
            current = urllib.request.urlopen(tag['href'])
            
            f = open(download_path + "\\" + os.path.basename(tag['href']), "wb")
            f.write(current.read())
            f.close
   
print('****')
print('DONE')
print('****')
     
#%%
